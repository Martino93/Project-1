# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import numpy as np
import plotly.express as px

# %%
import seaborn as sns; sns.set(style='ticks', color_codes=True)

# %%
file = pd.read_csv('./2017_2018.csv')
file = pd.DataFrame(file)
file2 = pd.read_csv('./2016_2017.csv')
file2 = pd.DataFrame(file2)
file3 = pd.read_csv('./2015_2016.csv')
file3 = pd.DataFrame(file3)
file4 = pd.read_csv('./2014_2015.csv')
file4 = pd.DataFrame(file4)
file5 = pd.read_csv('./2013_2014.csv')
file5 = pd.DataFrame(file5)
file6 = pd.read_csv('./2012_2013.csv')
file6 = pd.DataFrame(file6)
file7 = pd.read_csv('./2011_2012.csv')
file7 = pd.DataFrame(file7)
file8 = pd.read_csv('./2010_2011.csv')
file8 = pd.DataFrame(file8)
file9 = pd.read_csv('./2009_2010.csv')
file9 = pd.DataFrame(file9)
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (6,9,31,1725,1726,1727,1728,1729,1743,1815,1816,1817,1818,1823,1824,1830,1831,1879,1880,1881,1882,1883,1884,1885,1886,1887,1888,1889,1890,1891,1892,1893,1894,1895,1896,1897,1898,1909,1910,1911,1912,1913,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ...

# %%
# df = file[['UNITID','PREDDEG','COSTT4_A','COSTT4_P','NUM4_PUB','NUM4_PRIV']]
# df = df.loc[df['PREDDEG']==3]
# df = df.rename(columns = {
#     'UNITID': 'id',
#     'PREDDEG': 'degree',
#     'COSTT4_A': 'cost_attendance_public',
#     'COSTT4_P': 'cost_attendance_private',
#     'NUM4_PUB': 'num_students_public',
#     'NUM4_PRIV': 'num_students_private'
# })
# df = df.drop(columns = 'degree').fillna(0)
# df['cost_attendance'] = df['cost_attendance_public'] + df['cost_attendance_private']
# df['num_students'] = df['num_students_public'] + df['num_students_private']
# df = df.drop(columns = ['cost_attendance_public','cost_attendance_private','num_students_public','num_students_private','id'])
# df = df.dropna()
# df = df.loc[df['num_students']>5000]

# %%
df1_sat.head()
# Out:
#        id  sat_avg  completion_rate
# 0  100654    929.0           0.3503
# 1  100663   1195.0           0.5767
# 3  100706   1322.0           0.5297
# 4  100724    935.0           0.2994
# 5  100751   1278.0           0.6906

# %%
# 2017-2018 SAT_AVG vs Completion Rate
df1_sat = file[['UNITID','PREDDEG','SAT_AVG','C200_4']]
df1_sat = df1_sat.loc[df1_sat['PREDDEG']==3]
df1_sat = df1_sat.rename(columns = {
    'UNITID': 'id',
    'SAT_AVG': 'sat_avg',
    'C200_4': 'completion_rate'
})
df1_sat = df1_sat.drop(columns = ['PREDDEG']).dropna()

# 2016-2017 SAT_AVG vs Completion Rate
df2_sat = file2[['UNITID','PREDDEG','SAT_AVG','C200_4']]
df2_sat = df2_sat.loc[df2_sat['PREDDEG']==3]
df2_sat = df2_sat.rename(columns = {
    'UNITID': 'id',
    'SAT_AVG': 'sat_avg',
    'C200_4': 'completion_rate'
})
df2_sat = df2_sat.drop(columns = ['PREDDEG']).dropna()

# 2015-2016 SAT_AVG vs Completion Rate
df3_sat = file3[['UNITID','PREDDEG','SAT_AVG','C200_4']]
df3_sat = df3_sat.loc[df3_sat['PREDDEG']==3]
df3_sat = df3_sat.rename(columns = {
    'UNITID': 'id',
    'SAT_AVG': 'sat_avg',
    'C200_4': 'completion_rate'
})
df3_sat = df3_sat.drop(columns = ['PREDDEG']).dropna()

# 2014-2015 SAT_AVG vs Completion Rate
df4_sat = file4[['UNITID','PREDDEG','SAT_AVG','C200_4']]
df4_sat = df4_sat.loc[df4_sat['PREDDEG']==3]
df4_sat = df4_sat.rename(columns = {
    'UNITID': 'id',
    'SAT_AVG': 'sat_avg',
    'C200_4': 'completion_rate'
})
df4_sat = df4_sat.drop(columns = ['PREDDEG']).dropna()

# 2013-2014 SAT_AVG vs Completion Rate
df5_sat = file5[['UNITID','PREDDEG','SAT_AVG','C200_4']]
df5_sat = df5_sat.loc[df5_sat['PREDDEG']==3]
df5_sat = df5_sat.rename(columns = {
    'UNITID': 'id',
    'SAT_AVG': 'sat_avg',
    'C200_4': 'completion_rate'
})
df5_sat = df5_sat.drop(columns = ['PREDDEG']).dropna()

# 2012-2013 SAT_AVG vs Completion Rate
df6_sat = file6[['UNITID','PREDDEG','SAT_AVG','C200_4']]
df6_sat = df6_sat.loc[df6_sat['PREDDEG']==3]
df6_sat = df6_sat.rename(columns = {
    'UNITID': 'id',
    'SAT_AVG': 'sat_avg',
    'C200_4': 'completion_rate'
})
df6_sat = df6_sat.drop(columns = ['PREDDEG']).dropna()

# 2011-2012 SAT_AVG vs Completion Rate
df7_sat = file7[['UNITID','PREDDEG','SAT_AVG','C200_4']]
df7_sat = df7_sat.loc[df7_sat['PREDDEG']==3]
df7_sat = df7_sat.rename(columns = {
    'UNITID': 'id',
    'SAT_AVG': 'sat_avg',
    'C200_4': 'completion_rate'
})
df7_sat = df7_sat.drop(columns = ['PREDDEG']).dropna()

# 2010-2011 SAT_AVG vs Completion Rate
df8_sat = file8[['UNITID','PREDDEG','SAT_AVG','C200_4']]
df8_sat = df8_sat.loc[df8_sat['PREDDEG']==3]
df8_sat = df8_sat.rename(columns = {
    'UNITID': 'id',
    'SAT_AVG': 'sat_avg',
    'C200_4': 'completion_rate'
})
df8_sat = df8_sat.drop(columns = ['PREDDEG']).dropna()

# 2009-2010 SAT_AVG vs Completion Rate
df9_sat = file9[['UNITID','PREDDEG','SAT_AVG','C200_4']]
df9_sat = df9_sat.loc[df9_sat['PREDDEG']==3]
df9_sat = df9_sat.rename(columns = {
    'UNITID': 'id',
    'SAT_AVG': 'sat_avg',
    'C200_4': 'completion_rate'
})
df9_sat = df9_sat.drop(columns = ['PREDDEG']).dropna()

# %%
from functools import reduce
dataframes = [df1_sat,df2_sat,df2_sat,df4_sat,df5_sat,df6_sat,df7_sat,df8_sat,df9_sat]
df_merged = reduce(lambda left,right: pd.merge(left,right,on=['id'],how='inner'),dataframes)
df_merged.columns =['id','17-18_sat','17-18_success','16-17_sat','16-17_success','15-16_sat','15-16_success',\
             '14-15_sat','14-15_success','13-14_sat','13-14_success','12-13_sat','12-13_success',\
            '11-12_sat','11-12_success','10-11_sat','10-11_success','09-10_sat','09-10_success']
df_merged.head()
# Out:
#        id  17-18_sat  17-18_success  16-17_sat  16-17_success  15-16_sat  \
# 0  100654      929.0         0.3503      849.0         0.3755      849.0
# 1  100663     1195.0         0.5767     1125.0         0.5936     1125.0
# 2  100706     1322.0         0.5297     1257.0         0.5098     1257.0
# 3  100724      935.0         0.2994      825.0         0.2865      825.0
# 4  100751     1278.0         0.6906     1202.0         0.6782     1202.0
#
#    15-16_success  14-15_sat  14-15_success  13-14_sat  13-14_success  \
# 0         0.3755      827.0         0.3389      823.0         0.3520
# 1         0.5936     1107.0         0.5243     1146.0         0.4881
# 2         0.5098     1219.0         0.5169     1180.0         0.5048
# 3         0.2865      851.0         0.2904      830.0         0.3013
# 4         0.6782     1185.0         0.6875     1171.0         0.6837
#
#    12-13_sat  12-13_success  11-12_sat  11-12_success  10-11_sat  \
# ...

# %%
plt.figure(figsize=(12,8))
plt.subplot(3,3,1)
plt.scatter(df_merged['17-18_sat'],df_merged['17-18_success'],alpha=0.5, s=2)
plt.title('2017 - 2018')
plt.xlabel('Average SAT Score')
plt.ylabel('Completion Rate')
plt.subplot(3,3,2)
plt.scatter(df_merged['16-17_sat'],df_merged['16-17_success'], alpha= 0.5, s=2)
plt.title('2016 - 2017')
plt.xlabel('Average SAT Score')
plt.ylabel('Completion Rate')
plt.subplot(3,3,3)
plt.scatter(df_merged['15-16_sat'],df_merged['15-16_success'], alpha= 0.5, s=2)
plt.title('2015 - 2016')
plt.xlabel('Average SAT Score')
plt.ylabel('Completion Rate')
plt.subplot(3,3,4)
plt.scatter(df_merged['14-15_sat'],df_merged['14-15_success'], alpha= 0.5, s=2)
plt.title('2014 - 2015')
plt.xlabel('Average SAT Score')
plt.ylabel('Completion Rate')
plt.subplot(3,3,5)
plt.scatter(df_merged['13-14_sat'],df_merged['13-14_success'], alpha= 0.5, s=2)
plt.title('2013 - 2014')
plt.xlabel('Average SAT Score')
plt.ylabel('Completion Rate')
plt.subplot(3,3,6)
plt.scatter(df_merged['12-13_sat'],df_merged['12-13_success'], alpha= 0.5, s=2)
plt.title('2012 - 2013')
plt.xlabel('Average SAT Score')
plt.ylabel('Completion Rate')
plt.subplot(3,3,7)
plt.scatter(df_merged['11-12_sat'],df_merged['11-12_success'], alpha= 0.5, s=2)
plt.title('2011 - 2012')
plt.xlabel('Average SAT Score')
plt.ylabel('Completion Rate')
plt.subplot(3,3,8)
plt.scatter(df_merged['10-11_sat'],df_merged['10-11_success'], alpha= 0.5, s=2)
plt.title('2010 - 2011')
plt.xlabel('Average SAT Score')
plt.ylabel('Completion Rate')
plt.subplot(3,3,9)
plt.scatter(df_merged['09-10_sat'],df_merged['09-10_success'], alpha= 0.5, s=2)
plt.title('2009 - 2010')
plt.xlabel('Average SAT Score')
plt.ylabel('Completion Rate')
plt.tight_layout(pad=0.5, w_pad=3, h_pad=3)
plt.show()

# %%
#Regressions-------
linreg = LinearRegression()
#2017-2018
x1 =  np.array(df_merged['17-18_sat'].tolist()).reshape((-1,1))
y1 = np.array(df_merged['17-18_success'].tolist())
reg1 = linreg.fit(x1,y1)
m1 = linreg.coef_
rsq1 = linreg.score(x1,y1)

#2016-2017
x2 =  np.array(df_merged['16-17_sat'].tolist()).reshape((-1,1))
y2 = np.array(df_merged['16-17_success'].tolist())
reg2 = linreg.fit(x2,y2)
m2 = linreg.coef_
rsq2 = linreg.score(x2,y2)

#2015-2016
x3 =  np.array(df_merged['15-16_sat'].tolist()).reshape((-1,1))
y3 = np.array(df_merged['15-16_success'].tolist())
reg3 = linreg.fit(x3,y3)
m3 = linreg.coef_
rsq3 = linreg.score(x3,y3)

#2014-2015
x4 =  np.array(df_merged['14-15_sat'].tolist()).reshape((-1,1))
y4 = np.array(df_merged['14-15_success'].tolist())
reg4 = linreg.fit(x4,y4)
m4 = linreg.coef_
rsq4 = linreg.score(x4,y4)

#2013-2014
x5 =  np.array(df_merged['13-14_sat'].tolist()).reshape((-1,1))
y5 = np.array(df_merged['13-14_success'].tolist())
reg5 = linreg.fit(x5,y5)
m5 = linreg.coef_
rsq5 = linreg.score(x5,y5)

#2012-2013
x6 =  np.array(df_merged['12-13_sat'].tolist()).reshape((-1,1))
y6 = np.array(df_merged['12-13_success'].tolist())
reg6 = linreg.fit(x6,y6)
m6 = linreg.coef_
rsq6 = linreg.score(x6,y6)

#2011-2012
x7 =  np.array(df_merged['11-12_sat'].tolist()).reshape((-1,1))
y7 = np.array(df_merged['11-12_success'].tolist())
reg7 = linreg.fit(x7,y7)
m7 = linreg.coef_
rsq7 = linreg.score(x7,y7)

#2010-2011
x8 =  np.array(df_merged['10-11_sat'].tolist()).reshape((-1,1))
y8 = np.array(df_merged['10-11_success'].tolist())
reg8 = linreg.fit(x8,y8)
m8 = linreg.coef_
rsq8 = linreg.score(x8,y8)

#2009-2010
x9 =  np.array(df_merged['09-10_sat'].tolist()).reshape((-1,1))
y9 = np.array(df_merged['09-10_success'].tolist())
reg9 = linreg.fit(x9,y9)
m9 = linreg.coef_
rsq9 = linreg.score(x9,y9)

list(map(float,[m1,m2,m3,m4,m5,m6,m7,m8,m9]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-bd79767c0660> in <module>
#       2 linreg = LinearRegression()
#       3 #2017-2018
# ----> 4 x1 =  np.array(df_merged['17-18_sat'].tolist()).reshape((-1,1))
#       5 y1 = np.array(df_merged['17-18_success'].tolist())
#       6 reg1 = linreg.fit(x1,y1)
#
# NameError: name 'df_merged' is not defined

# %%
slopes = list(map(float,[m1,m2,m3,m4,m5,m6,m7,m8,m9]))
a = range(len(slopes))
plt.scatter(a,slopes)

# %% [markdown]
# # Math and Reading vs Success Rate
